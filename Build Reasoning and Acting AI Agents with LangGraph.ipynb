# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **ReAct: Build Reasoning and Acting AI Agents with LangGraph**

# %% [markdown]
# Estimated time needed: **90** minutes

# %% [markdown]
# You're a software engineer on a mission: build an AI agent that doesn't just respond—it thinks. In this lab, you'll step into the role of an AI architect, designing a smart assistant that solves tough problems by reasoning through them and taking purposeful actions.
#
# Using the ReAct (Reasoning + Acting) framework, you'll teach your agent to think step by step, consult tools like search engines or calculators, and adapt on the fly. It’s not just about answers—it’s about how the agent gets there.
#
# By the end of the lab, your AI will face a mystery that can’t be solved with knowledge alone. It will need logic, resourcefulness, and the ability to act—just like you, the engineer who built it.
#
# ## What is ReAct?
#
# **ReAct** stands for **Reasoning + Acting**. It's a framework that combines:
#
# 1. **Reasoning**: The agent thinks through problems step by step, maintaining an internal dialogue about what it needs to do.
# 2. **Acting**: The agent can use external tools (search engines, calculators, APIs) to gather information or perform actions.
# 3. **Observing**: The agent processes the results from its actions and incorporates them into its reasoning.
#
# This creates a powerful loop: **Think → Act → Observe → Think → Act → ...**
#
# ### Why ReAct Matters
#
# Traditional language models are limited by their training data cutoff and can't access real-time information. ReAct agents overcome this by:
# - Accessing current information through web searches
# - Performing calculations with specialized tools
# - Breaking down complex problems into manageable steps
# - Adapting their approach based on intermediate results

# %% [markdown]
# ## __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup-&-Installation">Setup & Installation</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Understanding-Tools-in-ReAct">Understanding Tools in ReAct</a>
#         <ol>
#             <li><a href="#1.-Web-Search-Tool">1. Web Search Tool</a></li>
#             <li><a href="#Theory-behind-Web-Search-Tools">Theory behind Web Search Tools</a></li>
#             <li><a href="#Testing-the-Search-Tool">Testing the Search Tool</a></li>
#             <li><a href="#2.-Clothing-Recommendation-Tool">2. Clothing Recommendation Tool</a></li>
#             <li><a href="#Why-this-Tool-Matters">Why this Tool Matters</a></li>
#             <li><a href="#Creating-the-tool-Registry">Creating the tool Registry</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Setting-up-the-Language-Model">Setting up the Language Model</a>
#         <ol>
#             <li><a href="#Initializing-the-AI-Model">Initializing the AI Model</a></li>
#             <li><a href="#Creating-the-System-Prompt">Creating the System Prompt</a></li>
#             <li><a href="#The-System-Prompt's-Role">The System Prompt's Role</a></li>
#             <li><a href="#Binding-Tools-to-the-Model">Binding Tools to the Model</a></li>
#             <li>
#                 <a href="#Understanding-Agent-State">Understanding Agent State</a>
#                 <ol>
#                     <li><a href="#What-is-Agent-State?">What is Agent State?</a></li>
#                     <li><a href="#Demonstrating-State-Management">Demonstrating State Management</a></li>
#                 </ol>
#             </li>
#             <li>
#                 <a href="#Manual-ReAct-Execution-(Understanding-the-Flow)">Manual ReAct Execution (Understanding the Flow)</a>
#                 <ol>
#                     <li><a href="#Step-1:-Initial-Query-Processing">Step 1: Initial Query Processing</a></li>
#                     <li><a href="#Step-2:-Tool-Execution">Step 2: Tool Execution</a></li>
#                     <li><a href="#Step-3:-Processing-Results-and-Next-Action">Step 3: Processing Results and Next Action</a></li>
#                     <li><a href="#Step-4:-Final-Response-Generation">Step 4: Final Response Generation</a></li>
#                 </ol>
#             </li>
#             <li>
#                 <a href="#Automating-ReAct-with-Graphs">Automating ReAct with Graphs</a>
#                 <ol>
#                     <li><a href="#Why-Use-Graphs?">Why Use Graphs?</a></li>
#                     <li><a href="#Building-the-Core-Functions">Building the Core Functions</a></li>
#                     <li><a href="#Constructing-the-State-Graph">Constructing the State Graph</a></li>
#                     <li><a href="#Visualizing-the-Graph">Visualizing the Graph</a></li>
#                 </ol>
#             </li>
#             <li>
#                 <a href="#Running-the-Complete-ReAct-Agent">Running the Complete ReAct Agent</a>
#                 <ol>
#                     <li><a href="#Final-Execution">Final Execution</a></li>
#                     <li><a href="#The-Complete-ReAct-Cycle">The Complete ReAct Cycle</a></li>
#                 </ol>
#             </li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Key-Takeaways">Key Takeaways</a>
#         <ol>
#             <li><a href="#What-Makes-ReAct-Powerful">What Makes ReAct Powerful</a></li>
#             <li><a href="#Best-Practices">Best Practices</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Exercises">Exercises</a>
#         <ol>
#             <li><a href="#Exercise-1---Build-a-Calculator-Tool">Exercise 1 - Build a Calculator Tool</a></li>
#             <li><a href="#Exercise-2---Create-a-News-Summary-Tool">Exercise 2 - Create a News Summary Tool</a></li>
#         </ol>
#     </li>
#     <li><a href="#Testing-Your-Solutions">Testing Your Solutions</a></li>
#     <li><a href="#Authors">Authors</a></li>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
#  - Use the ReAct framework to solve multi-step problems with external tools
#  - Teach an AI agent to reason step by step, take actions, and adapt based on results
#  - Build a smart assistant that can handle tasks requiring logic and tool use

# %% [markdown]
# ----

# %% [markdown]
# ## Setup & Installation

# %% [markdown]
# For this lab, we will be using the following libraries:
#
#
# - [`LangGraph`](https://www.langchain.com/langgraph): A framework for building stateful, multi-step AI applications using graphs.
# - [`LangChain`](https://www.langchain.com/): A toolkit that provides tools and abstractions for working with language models.
# - [`LangChain-OpenAI`](https://python.langchain.com/docs/integrations/llms/openai/): OpenAI integration for LangChain.
# - [`LangChain-Community`](https://python.langchain.com/api_reference/community/index.html): Community-contributed tools and integrations.

# %% [markdown]
# ### Installing Required Libraries

# %%
# !pip install -U langgraph langchain-openai
# Out:
# Collecting langgraph
#   Downloading langgraph-1.2.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.2.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-core<2,>=1.4.0 (from langgraph)
#   Downloading langchain_core-1.4.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-4.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph)
#   Downloading langgraph_sdk-0.3.14-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pydantic>=2.7.4 in /opt/conda/lib/python3.12/site-packages (from langgraph) (2.10.6)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai)
#   Downloading openai-2.36.0-py3-none-any.whl.metadata (31 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.13.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (1.33)
# Collecting langchain-protocol>=0.0.14 (from langchain-core<2,>=1.4.0->langgraph)
#   Downloading langchain_protocol-0.0.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2,>=1.4.0->langgraph)
#   Downloading langsmith-0.8.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/conda/lib/python3.12/site-packages (from langchain-core<2,>=1.4.0->langgraph) (4.12.2)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2,>=1.4.0->langgraph)
#   Downloading uuid_utils-0.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph)
#   Downloading ormsgpack-1.12.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /opt/conda/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph)
#   Downloading orjson-3.11.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading jiter-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.1)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core<2,>=1.4.0->langgraph)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (2.27.2)
# Collecting regex (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.5.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.26.0->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.0->langgraph) (3.0.0)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.3.0)
# Downloading langgraph-1.2.0-py3-none-any.whl (234 kB)
# Downloading langchain_openai-1.2.1-py3-none-any.whl (98 kB)
# Downloading langchain_core-1.4.0-py3-none-any.whl (548 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.1/548.1 kB 26.5 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-4.1.0-py3-none-any.whl (56 kB)
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.3.14-py3-none-any.whl (97 kB)
# Downloading openai-2.36.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.0 MB/s eta 0:00:00
# Downloading tiktoken-0.13.0-cp312-cp312-manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.4 MB/s eta 0:00:00
# Downloading xxhash-3.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Downloading jiter-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (353 kB)
# Downloading langchain_protocol-0.0.15-py3-none-any.whl (7.0 kB)
# Downloading langsmith-0.8.4-py3-none-any.whl (398 kB)
# Downloading orjson-3.11.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (134 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading uuid_utils-0.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
# Downloading regex-2026.5.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (801 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.2/801.2 kB 25.1 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: xxhash, uuid-utils, typing-extensions, regex, ormsgpack, orjson, jiter, tiktoken, requests-toolbelt, langchain-protocol, openai, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-openai, langgraph-prebuilt, langgraph
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# Successfully installed jiter-0.14.0 langchain-core-1.4.0 langchain-openai-1.2.1 langchain-protocol-0.0.15 langgraph-1.2.0 langgraph-checkpoint-4.1.0 langgraph-prebuilt-1.1.0 langgraph-sdk-0.3.14 langsmith-0.8.4 openai-2.36.0 orjson-3.11.9 ormsgpack-1.12.2 regex-2026.5.9 requests-toolbelt-1.0.0 tiktoken-0.13.0 typing-extensions-4.15.0 uuid-utils-0.15.0 xxhash-3.7.0

# %%
# %%capture
# !pip install langgraph==0.3.34 langchain-openai==0.3.14 langchainhub==0.1.21 langchain==0.3.24 pygraphviz==1.14 langchain-community==0.3.23

# %% [markdown]
# ### Understanding Tools in ReAct
#
# Tools are the "acting" part of ReAct. They give the agent capabilities beyond just generating text. Let's build two essential tools:
#
# #### 1. Web Search Tool
# ### Tavily Search API Key Setup
#
# We'll use Tavily search as our external research tool. You can get an API key at https://app.tavily.com/sign-in
#
#
# **Disclaimer:** Signing up for Tavily provides you with free credits, more than enough for this project's needs. If you require additional credits for further use, please add them at your own discretion.
#
# ![image.png](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/UjJx1-0vss4_3lwsUF8n0w/image.png)
#
# You need to copy the key from Tavily's API website and paste the key on the line ```os.environ["TAVILY_API_KEY"] = "YOUR_KEY_HERE"```

# %%
import warnings 
warnings.filterwarnings('ignore')

from langchain_community.tools.tavily_search import TavilySearchResults
from langchain.tools import tool
import os
import json

os.environ["TAVILY_API_KEY"] = "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"

# Initialize the Tavily search tool
search = TavilySearchResults()

@tool
def search_tool(query: str):
    """
    Search the web for information using Tavily API.

    :param query: The search query string
    :return: Search results related to the query
    """
    return search.invoke(query)

# %% [markdown]
# ### Theory behind Web Search Tools:
# - Enable real-time information retrieval
# - Overcome the knowledge cutoff limitation of language models
# - Return structured data that the agent can process and reason about
#
# ### Testing the Search Tool

# %%
search_tool.invoke("What's the weather like in Tokyo today?")
# Out:
# [{'title': 'Highest temperature in Tokyo on May 15? Trading Odds & Predictions (May 15, 2026) | Polymarket',
#   'url': 'https://polymarket.com/event/highest-temperature-in-tokyo-on-may-15-2026',
#   'content': "Trader consensus on Polymarket heavily favors a Tokyo high of 23°C at 46.5% implied probability, closely tracking the Japan Meteorological Agency's seasonal normal of 23.8°C for May 15, despite the agency's latest forecast (issued May 14 evening) projecting a maximum of 25°C under partly cloudy skies clearing later. This positioning reflects caution amid morning observations starting near 17°C with scattered clouds potentially capping afternoon heating via reduced solar insolation, compounded by light winds and urban sea breezes typical for early May. Over the past week, highs hovered in the low-to-mid 20s°C, with May 13 peaking near 26°C before a slight cool-down. Real-time JMA hourly updates this afternoon will be pivotal as the market nears resolution based on official Tokyo station [...] Trader consensus on Polymarket heavily favors a Tokyo high of 23°C at 46.5% implied probability, closely tracking the Japan Meteorological Agency's seasonal normal of 23.8°C for May 15, despite the agency's latest forecast (issued May 14 evening) projecting a maximum of 25°C under partly cloudy skies clearing later. This positioning reflects caution amid morning observations starting near 17°C with scattered clouds potentially capping afternoon heating via reduced solar insolation, compounded by light winds and urban sea breezes typical for early May. Over the past week, highs hovered in the low-to-mid 20s°C, with May 13 peaking near 26°C before a slight cool-down. Real-time JMA hourly updates this afternoon will be pivotal as the market nears resolution based on official Tokyo station [...] the market nears resolution based on official Tokyo station records.",
#   'score': 0.99984884},
#  {'title': 'Tokyo, Tokyo, Japan Monthly Weather | AccuWeather',
#   'url': 'https://www.accuweather.com/en/jp/tokyo/226396/may-weather/226396',
#   'content': "### Video\n\n## Monthly\n\n## May\n\n## 2026\n\n## 10-Day\n\nBreezy this afternoon\nPlenty of sunshine\nSunny and very warm\nWarm; breezy in the afternoon\nVery warm; breezy in the p.m.\nCloudy\nCloudy with a little rain\nHumid; an a.m. shower or two\nMostly cloudy and humid\nSun through high clouds\nMostly cloudy\nRain\nPartly sunny and humid\nDecreasing clouds; less humid\nMostly cloudy\nMostly cloudy\nHumid with rain\nCloudy and humid\nRain becoming steadier\nCloudy with a little rain\nDecreasing clouds\nMostly sunny\nCloudy\n\n## Temperature Graph\n\n## May Weather in Tokyo\n\n## Further Ahead\n\nFurther Ahead\n\n### June 2026\n\n### July 2026\n\n### August 2026\n\n## Around the Globe\n\nAround the Globe\n\n### Hurricane Tracker\n\n### Severe Weather\n\n### Radar & Maps\n\n### News\n\n### Video\n\nTop Stories\n\nWeather Forecasts [...] # Tokyo, Tokyo\n\nTokyo\n\nTokyo\n\n## Around the Globe\n\nAround the Globe\n\n### Hurricane Tracker\n\n### Severe Weather\n\n### Radar & Maps\n\n### News & Features\n\n### Astronomy\n\n### Business\n\n### Climate\n\n### Health\n\n### Recreation\n\n### Sports\n\n### Travel\n\n### Warnings\n\n### Data Suite\n\n### Forensics\n\n### Advertising\n\n### Superior Accuracy™\n\n### Video\n\n## Monthly\n\n## May\n\n## 2026\n\n## 10-Day [...] ### News\n\n### Video\n\nTop Stories\n\nWeather Forecasts\n\nEl Nino is almost here, and it may rival the strongest in history\n\n10 hours ago\n\nSevere Weather\n\nMulti-day severe risk in the central US; biggest threat Sunday, Monday\n\n7 hours ago\n\nWeather Forecasts\n\nSummerlike heat, humidity to send RealFeel temps near 100 F in East\n\n11 hours ago\n\nRecreation\n\nPregnant hiker, dogs rescued from heat on Florida trail\n\n1 day ago\n\nWeather Forecasts\n\nStorm to bring needed rain to New England, help drought improve\n\n10 hours ago\n\nFeatured Stories\n\nHealth\n\nWet spring, more mice? The weather link behind rare hantavirus risk\n\n10 hours ago\n\nClimate\n\nTurkmenistan's fiery 'Gates of Hell' crater is dimming\n\n10 hours ago\n\nWeather News\n\nHere's how New York residents can get free A/C this summer\n\n1 day ago\n\nRecreation",
#   'score': 0.9985335},
#  {'title': 'Toyo, Tokyo, Japan Monthly Weather | AccuWeather',
#   'url': 'https://www.accuweather.com/en/jp/toyo/1511679/may-weather/1511679',
#   'content': "### Video\n\n## Monthly\n\n## May\n\n## 2026\n\n## 10-Day\n\nBreezy this afternoon\nPlenty of sunshine\nSunny and very warm\nWarm; breezy in the afternoon\nVery warm; breezy in the p.m.\nCloudy\nCloudy with a little rain\nHumid; an a.m. shower or two\nMostly cloudy and humid\nSun through high clouds\nMostly cloudy\nRain\nPartly sunny and humid\nDecreasing clouds; less humid\nMostly cloudy\nMostly cloudy\nHumid with rain\nCloudy and humid\nRain becoming steadier\nCloudy with a little rain\nDecreasing clouds\nMostly sunny\nCloudy\n\n## Temperature Graph\n\n## May Weather in Toyo\n\n## Further Ahead\n\nFurther Ahead\n\n### June 2026\n\n### July 2026\n\n### August 2026\n\n## Around the Globe\n\nAround the Globe\n\n### Hurricane Tracker\n\n### Severe Weather\n\n### Radar & Maps\n\n### News\n\n### Video\n\nTop Stories\n\nWeather Forecasts [...] # Toyo, Tokyo\n\nToyo\n\nTokyo\n\n## Around the Globe\n\nAround the Globe\n\n### Hurricane Tracker\n\n### Severe Weather\n\n### Radar & Maps\n\n### News & Features\n\n### Astronomy\n\n### Business\n\n### Climate\n\n### Health\n\n### Recreation\n\n### Sports\n\n### Travel\n\n### Warnings\n\n### Data Suite\n\n### Forensics\n\n### Advertising\n\n### Superior Accuracy™\n\n### Video\n\n## Monthly\n\n## May\n\n## 2026\n\n## 10-Day [...] ### News\n\n### Video\n\nTop Stories\n\nWeather Forecasts\n\nEl Nino is almost here, and it may rival the strongest in history\n\n10 hours ago\n\nSevere Weather\n\nMulti-day severe risk in the central US; biggest threat Sunday, Monday\n\n7 hours ago\n\nWeather Forecasts\n\nSummerlike heat, humidity to send RealFeel temps near 100 F in East\n\n11 hours ago\n\nRecreation\n\nPregnant hiker, dogs rescued from heat on Florida trail\n\n1 day ago\n\nWeather Forecasts\n\nStorm to bring needed rain to New England, help drought improve\n\n10 hours ago\n\nFeatured Stories\n\nHealth\n\nWet spring, more mice? The weather link behind rare hantavirus risk\n\n10 hours ago\n\nClimate\n\nTurkmenistan's fiery 'Gates of Hell' crater is dimming\n\n10 hours ago\n\nWeather News\n\nHere's how New York residents can get free A/C this summer\n\n1 day ago\n\nRecreation",
#   'score': 0.998487},
#  {'title': 'Tokyo, Japan Weather Conditions | Weather Underground',
#   'url': 'https://www.wunderground.com/weather/jp/tokyo',
#   'content': "# Tokyo, Tokyo Prefecture, Japan Weather Conditionsstar\\_ratehome\n\nicon\n\nThank you for reporting this station. We will review the data in question.\n\nYou are about to report this weather station for bad data. Please select the information that is incorrect.\n\nSee more\n\n(Reset Map)\n\nNo PWS\n\nReset Map, or Add PWS.\n\naccess\\_time 2:36 PM JST on May 15, 2026 (GMT +9) | Updated 12 seconds ago\n\nicon\n\nSunny\n\nGusts 2 °mph\n\nToday's temperature is forecast to be NEARLY THE SAME as yesterday.\n\nicon\nicon\nicon\nicon\nicon\nicon\nicon\nicon\nAccess Logo\n\nWe recognize our responsibility to use data and technology for good. We may use or share your data with our data vendors. Take control of your data.\n\nThe Weather Company Logo\nThe Weather Channel Logo\nWeather Underground Logo\nStorm Radar Logo [...] © The Weather Company, LLC 2026",
#   'score': 0.9953544},
#  {'title': 'Tokyo, 13, JP Current Weather - The Weather Network',
#   'url': 'https://www.theweathernetwork.com/en/city/jp/tokyo/tokyo/current',
#   'content': "# Tokyo, 13, JP Current Weather\n\n## Hourly\n\nSunny\nPOP\nSunny\nPOP\nSunny\nPOP\nSunny\nPOP\nSunny\nPOP\n\n## Today’s Conditions\n\n## \n\n## 14 Days\n\n## \n\n## Monthly\n\n## Radar Map\n\n## News\n\n## Weather for more locations\n\n## Weather FAQ for Tokyo, 13, JP\n\n## Support\n\n## Weather Tools\n\n## Follow Us\n\nfacebook icon\ninstagram icon\nyoutube icon\ntiktok icon\nthreads icon\ntwitter icon\n\nCanada's #1 most trusted weather brand and news source\\\n\nNumber 1 Most Trusted by Canadians 2026 - BrandSpark most trusted award\nThe weather network and meteomedia number 1 trusted news source\n\n\\2026 BrandSpark® Canadian Trust Study & 2026 Pollara Trust in Media Study",
#   'score': 0.6370308}]

# %% [markdown]
# This test demonstrates how the agent can access current information that wasn't available during training.
#
# #### 2. Clothing Recommendation Tool

# %%
@tool
def recommend_clothing(weather: str) -> str:
    """
    Returns a clothing recommendation based on the provided weather description.

    This function examines the input string for specific keywords or temperature indicators 
    (e.g., "snow", "freezing", "rain", "85°F") to suggest appropriate attire. It handles 
    common weather conditions like snow, rain, heat, and cold by providing simple and practical 
    clothing advice.

    :param weather: A brief description of the weather (e.g., "Overcast, 64.9°F")
    :return: A string with clothing recommendations suitable for the weather
    """
    weather = weather.lower()
    if "snow" in weather or "freezing" in weather:
        return "Wear a heavy coat, gloves, and boots."
    elif "rain" in weather or "wet" in weather:
        return "Bring a raincoat and waterproof shoes."
    elif "hot" in weather or "85" in weather:
        return "T-shirt, shorts, and sunscreen recommended."
    elif "cold" in weather or "50" in weather:
        return "Wear a warm jacket or sweater."
    else:
        return "A light jacket should be fine."

# %% [markdown]
# **Why this Tool Matters:**
# - Demonstrates domain-specific reasoning
# - Shows how tools can process and interpret data from other tools
# - Illustrates the composability of ReAct systems
#
# #### Creating the Tool Registry

# %%
tools=[search_tool,recommend_clothing]

tools_by_name={ tool.name:tool for tool in tools}

# %% [markdown]
# This registry allows the agent to dynamically select and invoke the appropriate tool based on the task at hand.
#
# ## Setting Up the Language Model
#
# ### Initializing the AI Model

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool

model = ChatOpenAI(model="gpt-4o-mini")

# %% [markdown]
# We're using GPT-4o-mini as our reasoning engine. This model will:
# - Analyze user queries
# - Decide which tools to use
# - Process tool results
# - Generate final responses
#
# ### Creating the System Prompt

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, ToolMessage,SystemMessage

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", """
You are a helpful AI assistant that thinks step-by-step and uses tools when needed.

When responding to queries:
1. First, think about what information you need
2. Use available tools if you need current data or specific capabilities  
3. Provide clear, helpful responses based on your reasoning and any tool results

Always explain your thinking process to help users understand your approach.
"""),
    MessagesPlaceholder(variable_name="scratch_pad")
])

# %% [markdown]
# **The System Prompt's Role:**
# - Defines the agent's behavior and personality
# - Establishes the reasoning pattern (think → act → observe)
# - Encourages transparency in the decision-making process
#
# ### Binding Tools to the Model

# %%
model_react=chat_prompt|model.bind_tools(tools)

# %% [markdown]
# This creates a model that can:
# - Understand when to use tools
# - Generate properly formatted tool calls
# - Process tool results in context
#
# ## Understanding Agent State
#
# ### What is Agent State?
#
# In ReAct, state management is crucial, as the agent must maintain context across multiple reasoning and acting steps.

# %%
from typing import (Annotated,Sequence,TypedDict)
from langchain_core.messages import BaseMessage
from langgraph.graph.message import add_messages

class AgentState(TypedDict):
    """The state of the agent."""

    # add_messages is a reducer
    # See https://langchain-ai.github.io/langgraph/concepts/low_level/#reducers
    messages: Annotated[Sequence[BaseMessage], add_messages]

# %% [markdown]
# **Key Concepts:**
# - **State**: Contains the conversation history and context.
# - **Reducer**: `add_messages` automatically handles adding new messages to the conversation.
# - **Type Safety**: TypedDict ensures our state structure is well-defined.
#
# ### Demonstrating State Management

# %%
# Example conversation flow:
state: AgentState = {"messages": []}

# append a message using the reducer properly
state["messages"] = add_messages(state["messages"], [HumanMessage(content="Hi")])
print("After greeting:", state["messages"])

# add another message (e.g. a question)
state["messages"] = add_messages(state["messages"], [HumanMessage(content="Weather in NYC?")])
print("After question:", state)
# Out:
# After greeting: [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='17f9d05a-66c3-4b5f-86e7-b91c8905b127')]
# After question: {'messages': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='17f9d05a-66c3-4b5f-86e7-b91c8905b127'), HumanMessage(content='Weather in NYC?', additional_kwargs={}, response_metadata={}, id='8adaf4b5-f1d4-4d71-887f-8b6aa71b8e7f')]}

# %% [markdown]
# This demonstrates how the state accumulates context over the conversation.

# %% [markdown]
# ## Manual ReAct Execution (Understanding the Flow)
#
# Before building the automated graph, let's manually step through a ReAct cycle to understand what happens:
#
# ### Step 1: Initial Query Processing

# %%
dummy_state: AgentState = {
    "messages": [HumanMessage( "What's the weather like in Zurich, and what should I wear based on the temperature?")]}

response = model_react.invoke({"scratch_pad":dummy_state["messages"]})

dummy_state["messages"]=add_messages(dummy_state["messages"],[response])

# %% [markdown]
# **What Happens Here:**
# 1. The user asks a complex question requiring current data.
# 2. The model analyzes the query and realizes it needs to search for weather information.
# 3. The model generates a tool call for the search.

# %% [markdown]
# ### Step 2: Tool Execution

# %%
tool_call = response.tool_calls[-1]
print("Tool call:", tool_call)

tool_result = tools_by_name[tool_call["name"]].invoke(tool_call["args"])
print("Tool result preview:", tool_result[0]['title'])

tool_message = ToolMessage(
    content=json.dumps(tool_result),
    name=tool_call["name"],
    tool_call_id=tool_call["id"]
)
dummy_state["messages"] = add_messages(dummy_state["messages"], [tool_message])
# Out:
# Tool call: {'name': 'search_tool', 'args': {'query': 'current weather in Zurich'}, 'id': 'call_SsXWOhRetVBJmkxJJSVF9ma8', 'type': 'tool_call'}
# Tool result preview: Zurich weather in May 2026 | Zurich 14 day weather

# %% [markdown]
# **What Happens Here:**
# 1. Extract the tool call from the model's response.
# 2. Execute the tool using the specified arguments.
# 3. Create a ToolMessage containing the results.
# 4. Add the tool result to the conversation state.

# %% [markdown]
# ### Step 3: Processing Results and Next Action

# %%
response = model_react.invoke({"scratch_pad": dummy_state["messages"]})
dummy_state['messages'] = add_messages(dummy_state['messages'], [response])

# check if the model wants to use another tool
if response.tool_calls:
    tool_call = response.tool_calls[0]
    tool_result = tools_by_name[tool_call["name"]].invoke(tool_call["args"])
    tool_message = ToolMessage(
        content=json.dumps(tool_result),
        name=tool_call["name"],
        tool_call_id=tool_call["id"]
    )
    dummy_state['messages'] = add_messages(dummy_state['messages'], [tool_message])

# %% [markdown]
# **What Happens Here:**
# 1. The model processes the search results.
# 2. It realizes it needs to use the clothing recommendation tool.
# 3. It extracts weather information and calls the clothing tool.
# 4. It receives clothing recommendations based on the weather data.

# %% [markdown]
# ### Step 4: Final Response Generation

# %%
response = model_react.invoke({"scratch_pad": dummy_state["messages"]})
print("Final response generated:", response.content is not None)
print("More tools needed:", bool(response.tool_calls))
# Out:
# Final response generated: True
# More tools needed: False

# %% [markdown]
# **What Happens Here:**
# 1. The model has all necessary information.
# 2. It synthesizes weather data and clothing recommendations.
# 3. It generates a comprehensive response to the user.
# 4. No more tool calls needed—the reasoning cycle is complete.

# %% [markdown]
# ## Automating ReAct with Graphs
#
# ### Why Use Graphs?
#
# Manual ReAct execution is educational but impractical for real applications. LangGraph automates this process with a state machine that handles the reasoning loop automatically.
#
# ### Building the Core Functions
#
# #### Tool Execution Node

# %%
def tool_node(state: AgentState):
    """Execute all tool calls from the last message in the state."""
    outputs = []
    for tool_call in state["messages"][-1].tool_calls:
        tool_result = tools_by_name[tool_call["name"]].invoke(tool_call["args"])
        outputs.append(
            ToolMessage(
                content=json.dumps(tool_result),
                name=tool_call["name"],
                tool_call_id=tool_call["id"],
            )
        )
    return {"messages": outputs}

# %% [markdown]
# **Function Purpose:**
# - Automatically execute all tool calls from the model
# - Handle multiple simultaneous tool calls
# - Return properly formatted tool messages

# %% [markdown]
# #### Model Invocation Node

# %%
def call_model(state: AgentState):
    """Invoke the model with the current conversation state."""
    response = model_react.invoke({"scratch_pad": state["messages"]})
    return {"messages": [response]}

# %% [markdown]
# **Function Purpose:**
# - Call the ReAct-enabled model
# - Pass the full conversation context
# - Return the model's response (which may include tool calls)
#
# #### Decision Logic

# %%
def should_continue(state: AgentState):
    """Determine whether to continue with tool use or end the conversation."""
    messages = state["messages"]
    last_message = messages[-1]
    # If there is no function call, then we finish
    if not last_message.tool_calls:
        return "end"
    # Otherwise if there is, we continue
    else:
        return "continue"

# %% [markdown]
# **Function Purpose:**
# - Implement the control flow logic
# - Decide whether the agent needs to use more tools
# - Route the conversation to either tool execution or completion
#
# ### Constructing the State Graph

# %%
from langgraph.graph import StateGraph, END

# Define a new graph
workflow = StateGraph(AgentState)

# Define the two nodes we will cycle between
workflow.add_node("agent", call_model)
workflow.add_node("tools", tool_node)

# Add edges between nodes
workflow.add_edge("tools", "agent")  # After tools, always go back to agent

# Add conditional logic
workflow.add_conditional_edges(
    "agent",
    should_continue,
    {
        "continue": "tools",  # If tools needed, go to tools node
        "end": END,          # If done, end the conversation
    },
)

# Set entry point
workflow.set_entry_point("agent")

# Compile the graph
graph = workflow.compile()

# %% [markdown]
# **Graph Structure Explained:**
# 1. **Agent Node**: Where reasoning happens and tool calls are generated.
# 2. **Tools Node**: Where tool execution occurs.
# 3. **Conditional Edge**: Determines whether to continue or finish.
# 4. **Entry Point**: Conversation always starts with the agent reasoning.
# ### Visualizing the Graph

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %% [markdown]
# This visualization shows the flow: Agent → Decision → Tools → Agent → Decision → End

# %% [markdown]
# ## Running the Complete ReAct Agent
#
# ### Final Execution

# %%
def print_stream(stream):
    """Helper function for formatting the stream nicely."""
    for s in stream:
        message = s["messages"][-1]
        if isinstance(message, tuple):
            print(message)
        else:
            message.pretty_print()

inputs = {"messages": [HumanMessage(content="What's the weather like in Zurich, and what should I wear based on the temperature?")]}

print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# What's the weather like in Zurich, and what should I wear based on the temperature?
# ================================== Ai Message ==================================
# Tool Calls:
#   search_tool (call_epA47CWWpsMiIyXPYDeUr2cx)
#  Call ID: call_epA47CWWpsMiIyXPYDeUr2cx
#   Args:
#     query: current weather in Zurich
# ================================= Tool Message =================================
# Name: search_tool
#
# [{"title": "Zurich weather in May 2026 | Zurich 14 day weather", "url": "https://www.weather25.com/europe/switzerland/zurich?page=month&month=May", "content": "weather25.com\nSearch\nweather in Switzerland\nRemove from your favorite locations\nAdd to my locations\nShare\nweather in Switzerland\n\n# Zurich weather in May 2026\n\nLight rain shower\nLight rain shower\nCloudy\nLight drizzle\nPatchy rain possible\nLight rain shower\nPartly cloudy\nSunny\nSunny\nPartly cloudy\nPatchy light rain with thunder\nPatchy rain possible\nSunny\nThundery outbreaks possible\n\n## The average weather in Zurich in May\n\nThe temperatures in Zurich in May are quite cold with temperatures between 7\u00b0C and 19\u00b0C, warm clothes are a must.\n\nYou can expect rain for roughly half of the month of May in Zurich. We\u2019re expecting roughly 8 to 15 days of rain, so your rubber boots and umbrella are going to see plenty of use this month if you\u2019re keen on staying dry. [...] | 24 Partly cloudy 22\u00b0 /7\u00b0 | 25 Patchy light rain with thunder 25\u00b0 /10\u00b0 | 26 Patchy rain possible 24\u00b0 /11\u00b0 | 27 Sunny 25\u00b0 /11\u00b0 | 28 Thundery outbreaks possible 26\u00b0 /12\u00b0 | 29 Partly cloudy 19\u00b0 /7\u00b0 | 30 Partly cloudy 20\u00b0 /7\u00b0 |\n| 31 Sunny 19\u00b0 /7\u00b0 |  |  |  |  |  |  | [...] | Sun | Mon | Tue | Wed | Thu | Fri | Sat |\n ---  ---  --- \n|  |  |  |  |  | 1 Sunny 17\u00b0 /7\u00b0 | 2 Light rain shower 16\u00b0 /6\u00b0 |\n| 3 Patchy rain possible 16\u00b0 /6\u00b0 | 4 Light rain shower 16\u00b0 /6\u00b0 | 5 Light rain 13\u00b0 /7\u00b0 | 6 Light rain 14\u00b0 /6\u00b0 | 7 Light rain shower 15\u00b0 /5\u00b0 | 8 Moderate rain 17\u00b0 /6\u00b0 | 9 Light rain shower 20\u00b0 /7\u00b0 |\n| 10 Light rain shower 20\u00b0 /8\u00b0 | 11 Light rain shower 17\u00b0 /7\u00b0 | 12 Sunny 16\u00b0 /6\u00b0 | 13 Patchy rain possible 16\u00b0 /7\u00b0 | 14 Light rain shower 18\u00b0 /7\u00b0 | 15 Light rain shower 10\u00b0 /3\u00b0 | 16 Light rain shower 12\u00b0 /2\u00b0 |\n| 17 Cloudy 17\u00b0 /1\u00b0 | 18 Light drizzle 15\u00b0 /4\u00b0 | 19 Patchy rain possible 13\u00b0 /5\u00b0 | 20 Light rain shower 19\u00b0 /10\u00b0 | 21 Partly cloudy 22\u00b0 /7\u00b0 | 22 Sunny 22\u00b0 /7\u00b0 | 23 Sunny 23\u00b0 /6\u00b0 |", "score": 0.8805613}, {"title": "Z\u00fcrich, Zurich, Switzerland Monthly Weather | AccuWeather", "url": "https://www.accuweather.com/en/ch/zurich/2-316622_1_al/may-weather/2-316622_1_al", "content": "### Video\n\n## Monthly\n\n## May\n\n## 2026\n\n## 10-Day\n\nA little morning rain; cloudy\nCloudy with a bit of rain\nTimes of clouds and sun\nA couple of afternoon showers\nRain and drizzle in the p.m.\nAn afternoon shower in spots\nSome sun\nWarm with plenty of sun\nWarm with plenty of sun\nMostly sunny and warm\nWarm with plenty of sunshine\nSunny and remaining warm\nMostly cloudy\nClouds and sunshine\nAfternoon rain\nA little morning rain; cloudy\nSun, then clouds\nPartial sunshine\nPlenty of sun\nSunny\nPlenty of sun\nMostly sunny\nPartly sunny\n\n## Temperature Graph\n\n## May Weather in Zurich\n\n## Further Ahead\n\nFurther Ahead\n\n### June 2026\n\n### July 2026\n\n### August 2026\n\n## Around the Globe\n\nAround the Globe\n\n### Hurricane Tracker\n\n### Severe Weather\n\n### Radar & Maps\n\n### News\n\n### Video\n\nTop Stories [...] # Z\u00fcrich, Zurich\n\nZ\u00fcrich\n\nZurich\n\n## Around the Globe\n\nAround the Globe\n\n### Hurricane Tracker\n\n### Severe Weather\n\n### Radar & Maps\n\n### News & Features\n\n### Astronomy\n\n### Business\n\n### Climate\n\n### Health\n\n### Recreation\n\n### Sports\n\n### Travel\n\n### Warnings\n\n### Data Suite\n\n### Forensics\n\n### Advertising\n\n### Superior Accuracy\u2122\n\n### Video\n\n## Monthly\n\n## May\n\n## 2026\n\n## 10-Day [...] ### Radar & Maps\n\n### News\n\n### Video\n\nTop Stories\n\nWeather Forecasts\n\nEl Nino is almost here, and it may rival the strongest in history\n\n10 hours ago\n\nSevere Weather\n\nMulti-day severe risk in the c ...
# ================================== Ai Message ==================================
# Tool Calls:
#   recommend_clothing (call_bIBr1RqUzfhuek7KzmpsjAE7)
#  Call ID: call_bIBr1RqUzfhuek7KzmpsjAE7
#   Args:
#     weather: Cloudy with light rain, temperatures between 7°C and 19°C.
# ================================= Tool Message =================================
# Name: recommend_clothing
#
# "Bring a raincoat and waterproof shoes."
# ================================== Ai Message ==================================
#
# Currently, the weather in Zurich is cloudy with light rain, and temperatures vary from around 7°C to 19°C.
# Given this weather, I recommend wearing a raincoat and waterproof shoes to stay dry and comfortable. Layering could also be a good idea, so you can adjust your clothing as the temperature changes throughout the day.

# %% [markdown]
# **What You'll See:**
# 1. **Initial Reasoning**: Agent analyzes the query.
# 2. **Tool Call 1**: Searches for Zurich weather.
# 3. **Tool Result Processing**: Agent examines weather data.
# 4. **Tool Call 2**: Gets clothing recommendations.
# 5. **Final Synthesis**: Agent combines all information into a helpful response.

# %% [markdown]
# ### The Complete ReAct Cycle
#
# The final execution demonstrates the full ReAct pattern:
#
# 1. **Reasoning**: "I need current weather data for Zurich".
# 2. **Acting**: Calls search_tool("Zurich weather today").
# 3. **Observing**: Processes search results, extracts temperature.
# 4. **Reasoning**: "Now I need clothing recommendations for this temperature".
# 5. **Acting**: Calls recommend_clothing("temperature from search").
# 6. **Observing**: Gets clothing suggestions.
# 7. **Reasoning**: "I can now provide a complete answer".
# 8. **Final Response**: Synthesizes weather info and clothing recommendations.

# %% [markdown]
# ## Key Takeaways

# %% [markdown]
# ### What Makes ReAct Powerful
#
# 1. **Transparency**: You can see the agent's reasoning process.
# 2. **Adaptability**: The agent can handle unexpected results and change course.
# 3. **Extensibility**: It's easy to add new tools and capabilities.
# 4. **Reliability**: The structured approach reduces hallucination and improves accuracy

# %% [markdown]
# ### Best Practices
#
# 1. **Tool Design**: Make tools focused and reliable.
# 2. **Error Handling**: Plan for tool failures and unexpected results.
# 3. **Context Management**: Keep state manageable and relevant.
# 4. **User Experience**: Provide clear feedback about what the agent is doing.
#
# The ReAct framework represents a significant step toward more capable and trustworthy AI agents that can reason through complex problems and take meaningful actions in the real world.

# %% [markdown]
# # Exercises
#
# Now it's time to put your ReAct knowledge into practice! These exercises will help you build your own tools and extend the agent's capabilities.

# %% [markdown]
# ## Exercise 1 - Build a Calculator Tool
#
# **Objective:** Create a mathematical calculator tool that can handle complex calculations.
#
# Your task is to create a calculator tool that can perform mathematical operations. This tool should be able to handle expressions like "2 + 3 * 4", "sqrt(16)", and "sin(π/2)".
#
# ### Instructions:
# 1. Create a tool called `calculator_tool` using the `@tool` decorator.
# 2. The tool should accept a mathematical expression as a string.
# 3. Use Python's `eval()` function carefully (or better yet, use the `ast` module for safety).
# 4. Test your tool with various mathematical expressions.
# 5. Add your tool to the tools list and test it with the ReAct agent.
#
# ### Starter Code:

# %%
import math

import ast

import operator



# Allowed operators

allowed_operators = {

    ast.Add: operator.add,

    ast.Sub: operator.sub,

    ast.Mult: operator.mul,

    ast.Div: operator.truediv,

    ast.Pow: operator.pow,

    ast.Mod: operator.mod,

    ast.FloorDiv: operator.floordiv,

    ast.USub: operator.neg,

    ast.UAdd: operator.pos,

}



# Allowed math functions

allowed_functions = {

    "sqrt": math.sqrt,

    "sin": math.sin,

    "cos": math.cos,

    "tan": math.tan,

    "log": math.log,

    "log10": math.log10,

    "exp": math.exp,

    "abs": abs,

    "round": round,

}



# Allowed constants

allowed_constants = {

    "pi": math.pi,

    "π": math.pi,

    "e": math.e,

}





def safe_eval(node):

    """

    Safely evaluate AST nodes.

    """



    if isinstance(node, ast.Constant):

        if isinstance(node.value, (int, float)):

            return node.value

        raise ValueError("Only numbers are allowed")



    elif isinstance(node, ast.BinOp):

        left = safe_eval(node.left)

        right = safe_eval(node.right)

        operator_type = type(node.op)



        if operator_type in allowed_operators:

            return allowed_operators[operator_type](left, right)



        raise ValueError("Operator not allowed")



    elif isinstance(node, ast.UnaryOp):

        operand = safe_eval(node.operand)

        operator_type = type(node.op)



        if operator_type in allowed_operators:

            return allowed_operators[operator_type](operand)



        raise ValueError("Unary operator not allowed")



    elif isinstance(node, ast.Name):

        if node.id in allowed_constants:

            return allowed_constants[node.id]



        raise ValueError(f"Unknown constant: {node.id}")



    elif isinstance(node, ast.Call):

        if not isinstance(node.func, ast.Name):

            raise ValueError("Only simple function calls are allowed")



        function_name = node.func.id



        if function_name not in allowed_functions:

            raise ValueError(f"Function not allowed: {function_name}")



        args = [safe_eval(arg) for arg in node.args]

        return allowed_functions[function_name](*args)



    else:

        raise ValueError("Unsupported expression")





@tool

def calculator_tool(expression: str) -> str:

    """

    Safely evaluate mathematical expressions.



    :param expression: A mathematical expression as a string (e.g., "2 + 3 * 4")

    :return: The result of the calculation

    """



    try:

        parsed_expression = ast.parse(expression, mode="eval")

        result = safe_eval(parsed_expression.body)

        return str(result)



    except Exception as e:

        return f"Error: {str(e)}"





# Add calculator_tool to your tools list

tools = [

    calculator_tool

]



# Test the tool directly

print(calculator_tool.invoke("2 + 3 * 4"))

print(calculator_tool.invoke("sqrt(16)"))

print(calculator_tool.invoke("sin(pi / 2)"))

print(calculator_tool.invoke("250 * 15 / 100 + sqrt(144)"))



# Test with the ReAct agent:

# "What's 15% of 250 plus the square root of 144?"
# Out:
# 14
# 4.0
# 1.0
# 49.5

# %% [markdown]
# ## Exercise 2 - Create a News Summary Tool
#
# **Objective:** Build a tool that can fetch and summarize recent news articles.
#
# Create a news summarization tool that works with the existing search functionality. This tool should take search results and create concise summaries of news articles.
#
# ### Instructions:
# 1. Create a `news_summarizer_tool` that takes news content and creates summaries.
# 2. The tool should extract key information: headline, date, main points.
# 3. Format the output in a readable way.
# 4. Test it by asking the agent to "search for recent AI news and summarize the top 3 articles".
#
# ### Starter Code:

# %%
import re

@tool
def news_summarizer_tool(news_content: str) -> str:
    """
    Summarize news articles from search results.

    :param news_content: Raw news content or search results
    :return: A formatted summary of the news
    """

    try:
        if not news_content or news_content.strip() == "":
            return "No news content provided."

        # Split content into possible articles
        articles = re.split(r"\n\s*\n|Article\s+\d+:|Result\s+\d+:", news_content)

        summaries = []

        for article in articles:
            article = article.strip()

            if len(article) < 30:
                continue

            lines = [line.strip() for line in article.split("\n") if line.strip()]

            # Try to detect headline
            headline = lines[0] if lines else "No headline found"

            # Try to detect date
            date_pattern = r"\b(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*\.?\s+\d{1,2},?\s+\d{4}|\b\d{1,2}/\d{1,2}/\d{4}\b|\b\d{4}-\d{2}-\d{2}\b"
            date_match = re.search(date_pattern, article, re.IGNORECASE)
            date = date_match.group(0) if date_match else "Date not found"

            # Create main points from sentences
            sentences = re.split(r"(?<=[.!?])\s+", article)

            main_points = []
            for sentence in sentences:
                sentence = sentence.strip()

                if len(sentence) > 40 and sentence not in main_points:
                    main_points.append(sentence)

                if len(main_points) == 3:
                    break

            if not main_points:
                main_points = ["No clear main points found."]

            summary = f"""
Headline: {headline}
Date: {date}
Main Points:
- {main_points[0]}
"""

            if len(main_points) > 1:
                summary += f"- {main_points[1]}\n"

            if len(main_points) > 2:
                summary += f"- {main_points[2]}\n"

            summaries.append(summary.strip())

            # Summarize only top 3 articles
            if len(summaries) == 3:
                break

        if not summaries:
            return "Could not extract useful news summaries from the given content."

        final_summary = "News Summary:\n\n"
        final_summary += "\n\n---\n\n".join(summaries)

        return final_summary

    except Exception as e:
        return f"Error while summarizing news: {str(e)}"


# Add news_summarizer_tool to your tools list
tools = [
    news_summarizer_tool
]

# Test the tool directly
sample_news_content = """
Article 1:
OpenAI announces new AI model
May 15, 2026
OpenAI has announced a new artificial intelligence model with improved reasoning capabilities. The model is designed to help users with coding, writing, and research tasks. Experts say this could improve productivity across industries.

Article 2:
Google expands AI tools for developers
May 14, 2026
Google has introduced new AI tools for developers. These tools help programmers write code faster and debug applications more efficiently. The company says the tools will be available through its cloud platform.

Article 3:
AI adoption increases in healthcare
May 13, 2026
Hospitals are increasingly using AI to support diagnosis and patient care. AI systems can analyze medical images and assist doctors in identifying diseases earlier. Healthcare leaders say responsible AI use is important for patient safety.
"""

print(news_summarizer_tool.invoke(sample_news_content))


# Test with the ReAct agent:
# "Find recent news about artificial intelligence and give me a summary"
# Out:
# News Summary:
#
# Headline: OpenAI announces new AI model
# Date: May 15, 2026
# Main Points:
# - OpenAI announces new AI model
# May 15, 2026
# OpenAI has announced a new artificial intelligence model with improved reasoning capabilities.
# - The model is designed to help users with coding, writing, and research tasks.
# - Experts say this could improve productivity across industries.
#
# ---
#
# Headline: Google expands AI tools for developers
# Date: May 14, 2026
# Main Points:
# - Google expands AI tools for developers
# May 14, 2026
# Google has introduced new AI tools for developers.
# - These tools help programmers write code faster and debug applications more efficiently.
# - The company says the tools will be available through its cloud platform.
#
# ---
#
# Headline: AI adoption increases in healthcare
# Date: May 13, 2026
# Main Points:
# - AI adoption increases in healthcare
# May 13, 2026
# Hospitals are increasingly using AI to support diagnosis and patient care.
# - AI systems can analyze medical images and assist doctors in identifying diseases earlier.
# - Healthcare leaders say responsible AI use is important for patient safety.

# %% [markdown]
# ## Testing Your Solutions
#
# For each exercise, test your implementation with these commands:

# %%
# Exercise 1 Test
inputs = {"messages": [HumanMessage(content="Calculate 15% of 250 plus the square root of 144")]}
print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# Calculate 15% of 250 plus the square root of 144
# ================================== Ai Message ==================================
#
# To solve the expression, we can break it down into two parts:
#
# 1. **Calculate 15% of 250**:
#
#    \[
#    15\% \, \text{of} \, 250 = \frac{15}{100} \times 250 = 37.5
#    \]
#
# 2. **Calculate the square root of 144**:
#
#    \[
#    \sqrt{144} = 12
#    \]
#
# 3. **Add the two results together**:
#
#    \[
#    37.5 + 12 = 49.5
#    \]
#
# Thus, the final result is \( 49.5 \).

# %%
# Exercise 2 Test  
inputs = {"messages": [HumanMessage(content="Find recent AI news and summarize the top 3 articles")]}
print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# Find recent AI news and summarize the top 3 articles
# ================================== Ai Message ==================================
# Tool Calls:
#   search_tool (call_6INi8vPQrNFgZt99UHlcd0Fu)
#  Call ID: call_6INi8vPQrNFgZt99UHlcd0Fu
#   Args:
#     query: recent AI news
# ================================= Tool Message =================================
# Name: search_tool
#
# [{"title": "AI News & Artificial Intelligence | TechCrunch", "url": "https://techcrunch.com/category/artificial-intelligence/", "content": "### Origin Lab raises $8M to help video game companies sell data to world-model builders\n\nDario Amodei\n\n### Anthropic courts a new kind of customer: small business owners\n\n### Amazon launches an AI shopping assistant for the search bar, powered by Alexa+\n\nTechCrunch Disrupt 2024 Aravind Srinivas\n\n### Introducing the 6 stages at TechCrunch Disrupt 2026 \u2014 built for today\u2019s tougher startup market\n\n### WhatsApp adds an incognito mode in Meta AI chats\n\nIndia's Prime Minister Narendra Modi (L) takes a group photo with AI company leaders including OpenAI CEO Sam Altman (C) and Anthropic CEO Dario Amodei (R) at the AI Impact Summit in New Delhi on February 19, 2026.\n\n### Anthropic now has more business customers than OpenAI, according to Ramp data [...] ### Clawdmeter turns your Claude Code usage stats into a tiny desktop dashboard\n\nCerebras Nasdaq opening bell\n\n### Cerebras raises $5.5B, then stock pops $108%, in the first huge tech IPO of 2026\n\n### Khosla Ventures is betting $10M on Ian Crosby, whose first startup, Bench, imploded\n\nChuck Robbins, CEO of Cisco Systems, speaks during the 2026 Semafor World Economy conference in Washington, DC, on April 15, 2026. (Photo by Kent NISHIMURA / AFP via Getty Images)\n\n### Cisco cuts nearly 4,000 jobs to spend more on AI, reports \u2018record quarterly revenue\u2019\n\nStartup Battlefield 200\n\n### Two weeks left: Startup Battlefield 200 applications close May 27\n\n### Wirestock raises $23M to supply creative multimodal data to AI labs [...] ### Poppy debuts a proactive AI assistant to help organize your digital life\n\nTechcrunch Sessions: AI Sara Hooker\n\n### Adaption aims big with AutoScientist, an AI tool that helps models train themselves\n\nClose-up of a physician's hands holding a tablet, used in a post about healthcare startup Regard\n\n### Medicare\u2019s new payment model is built for AI, and most of the tech world has no idea\n\n### Musk mulled handing OpenAI to his children, Altman testifies\n\nThe Claude logo is displayed on a smartphone screen placed on a reflective surface onto which a multitude of Claude logos are projected.\n\n### Anthropic warns investors against secondary platforms offering access to its shares\n\nSpaceX starship fully stacked\n\n### Report: Google and SpaceX in talks to put data centers into orbit", "score": 0.77994305}, {"title": "Artificial intelligence news: Chat AI, ChatGPT, AI generator, AI Chatbot and Bard | NBC News", "url": "https://www.nbcnews.com/artificial-intelligence", "content": "## Anthropic and SpaceX announce major partnership as AI arms race continues\n\nSpaceX's mega rocket Starship prepares for a test flight from Starbase in Boca Chica, Texas on  Nov. 18, 2024.\nSpaceX's mega rocket Starship prepares for a test flight from Starbase in Boca Chica, Texas on  Nov. 18, 2024.\n\n## OpenAI co-founder says he feared Musk would 'physically attack' him\n\nElon Musk v. OpenAI Trial Continues In California\nElon Musk v. OpenAI Trial Continues In California\n\n## Pennsylvania suing AI company after chatbot allegedly posed as a licensed doctor\n\nPennsylvania Governor Josh Shapiro Launches Re-election Campaign\nPennsylvania Governor Josh Shapiro Launches Re-election Campaign\n\n## A 'Devil Wears Prada 2' meme that viewers thought was AI slop was actually made by a human [...] ## Hallie Jackson NOW\n\n## 04:04\n\n### OpenAI sued by family of victim killed in FSU mass shooting\n\n## NBC News NOW\n\n## 02:33\n\n### Georgia Tech get three hours to build an app using Claude AI\n\n## Stay Tuned NOW\n\n## 03:54\n\n### AI-generated video supporting Spencer Pratt for mayor of L.A. goes viral adding to concern over fake campaign ads\n\n## Hallie Jackson NOW\n\n## 02:27\n\n### People are turning text message threads into fun songs using AI in a new trend on social media\n\n## NBC News ...
# ================================== Ai Message ==================================
#
# I've found some recent articles about AI news, and here are the top three summaries:
#
# 1. **AI News & Artificial Intelligence | TechCrunch**
#    - **Highlights**: TechCrunch reports on a variety of recent developments in AI, including:
#      - Origin Lab raising $8 million to assist video game companies in selling data.
#      - Anthropic gaining more business customers than OpenAI.
#      - Amazon's launch of an AI shopping assistant powered by Alexa.
#      - Cisco announcing job cuts to redirect funds towards AI investments, despite reporting record quarterly revenues.
#    - **Link**: [TechCrunch AI Section](https://techcrunch.com/category/artificial-intelligence/)
#
# 2. **Anthropic and SpaceX Announce Major Partnership | NBC News**
#    - **Highlights**: NBC News covers significant AI-related occurrences such as:
#      - A new partnership between Anthropic and SpaceX, indicating a collaborative approach in the AI arms race.
#      - Legal actions against AI companies, including a lawsuit against a chatbot that impersonated a licensed doctor.
#      - Concerns over AI-generated content misrepresenting real-world events, and notable campaigns using AI-generated videos going viral.
#    - **Link**: [NBC News AI Section](https://www.nbcnews.com/artificial-intelligence)
#
# 3. **Trends Shaping AI and Tech in 2026 | IBM**
#    - **Highlights**: IBM outlines predictions for AI in enterprise by 2026, suggesting:
#      - Increased focus on trust and security in AI applications.
#      - Shortcomings in AI’s return on investment (ROI) are expected to be overcome with new capabilities.
#      - The emergence of open-source reasoning models and more domain-specific, smaller AI models to optimize performance and ensure data sovereignty.
#    - **Link**: [IBM AI Predictions](https://www.ibm.com/think/news/ai-tech-trends-predictions-2026)
#
# These articles highlight the dynamic nature of the AI field, from partnerships and legal challenges to predictions for future developments. If you need further details on any specific topic, feel free to ask!

# %% [markdown]
# ## Authors

# %% [markdown]
# [Joseph Santarcangelo](https://author.skills.network/instructors/joseph_santarcangelo): Joseph has a Ph.D. in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
# [Tenzin Migmar](https://author.skills.network/instructors/tenzin_migmar): Hi, I'm Tenzin. I'm a data scientist intern at IBM interested in applying machine learning to solve difficult problems. Prior to joining IBM, I worked as a research assistant on projects exploring perspectivism and personalization within large language models. In my free time, I enjoy recreational programming and learning to cook new recipes.
#
# [Faranak Heidari](https://www.linkedin.com/in/faranakhdr/) is a data scientist and AI developer in IBM.

# %% [markdown]
# <!--#### Change Log

# %% [markdown]
# <!--
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-02-23|0.2|Elio Di Nino|Update library documentation|
# |2020-07-17|0.1|Sam|Create lab template|
# -->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
